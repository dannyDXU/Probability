# %% [markdown]
# # CS 237 Spring 2021, HW 02
#
# #### Due date: Thursday February 11th at Midnight (1 minute after 11:59pm on 2/11) via Gradescope (6 hour grace period)
#
# <strong> Late policy:</strong> You may submit the homework up to 24 hours late for a 10% penalty. Hence, the late deadline is Friday 2/2 at Midnight (with the same 6 hour grace period).
#
# #### General Instructions
#
# Please complete this notebook by filling in solutions where indicated. Be sure to "Restart and Run All" from the Kernel menu before <a href="https://www.cs.bu.edu/fac/snyder/cs237/HWSubmissionInstructions.html">submitting to Gradescope</a>.
#
# There are 8 analytical problems and 4 programming problems. An introductory video will be posted on YT Friday afternoon for
# the analytical problems, and the programming problems will be covered Friday in lab.

# %%
# Here are some imports which will be used in code that we write for CS 237

# IMPORTANT:     DO NOT MAKE ANY OTHER IMPORTS WITHOUT DISCUSSING WITH PROFESSOR SNYDER

# Imports used for the code in CS 237

import numpy as np                # arrays and functions which operate on arrays, plus math functions
import matplotlib.pyplot as plt   # normal plotting 
import math                       # You may use the math library if you really want, but
                                  #    I recommend you use the numpy library for all mathematical operations.
                                  #    Examples of use are in the notebook NumpyTutorial.ipynb on the class web site. 


from collections import Counter   # Essential for creating distributions from experiments

# %% [markdown]
# ## Analytical Problems
#
# The first 4 problems are from the textbook End of Chapter Problems for Chapter 1 <a href="https://www.probabilitycourse.com/chapter1/1_5_0_chapter1_problems.php">here</a>. If only certain parts of a problem are specified, then (naturally) just do those parts; if no such restriction is specified, you must do all parts of the problem.
#
#
# For Problems 5, 6, and 8, **Analyze** means to specify
# <ol>
# <li> The sample space S,
# <li> The probability function P,
# <li> The events given (i.e.,list or unambigiously specify the members of each event), and
# <li> The probability of each of the events.
# </ol>
#
# In some cases, additional information may be required. You may abbreviate or schematize as necessary, as long as the answer is perfectly clear.
#
# Sometimes it is useful to first write down a "pre-sample space" which helps to think about the actual sample space. This is often useful when the literal outcome of the random experiment is non-numeric but the sample space is numeric. You are not required to submit this pre-sample space in your solution, but I encourage you to take this step whenever possible.
#
# <strong>Example:</strong> Toss a fair coin (i.e., probably of heads is 0.5) and report the number of heads that appear. Let A = "one head appears."
# **Analyze.**
#
# <strong>Solution:</strong>  The pre-sample space is { T, H }. Then:
#
#            S = { 0,   1   }
#            P = { 0.5, 0.5 }
#            A = { 1 }
#            P(A) = 0.5

# %% [markdown]
# ### Problem 1 (Set Theory)
#
# Do problem 1 from the End of Chapter Problems for Chapter 1 in the textbook.

# %% [markdown]
# #### Solution:
#
# A.)
#
#      A = {1,2,3}
#
#      B = {2,3,4,5,6,7}
#
#      A U B = {1,2,3,4,5,6,7}
#
# B.)
#
#      A = {1,2,3}
#
#      B = {2,3,4,5,6,7}
#
#      C = {7,8,9,10}
#
#     (A U C) = {1,2,3,7,8,9,10}
#
#     (A U C)- B = {1,8,9,10}
#
# C.)
#
#      B = {2,3,4,5,6,7}
#
#      C = {7,8,9,10}
#
#      B - C = {2,3,4,5,6}
#
#
#      -
#      A = {4,5,6,7,8,9,10}
#      -
#      A U (B - C) = {2,3,4,5,6,7,8,9,10}
#
# D.)
#
#     No, it doesn't form a partition of S

# %% [markdown]
# ### Problem 2 (Set Theory)
#
# Do problem 6 from the End of Chapter Problems for Chapter 1 in the textbook.
#
#     |B∩A1|=10
#     |B∩A2|=20
#     |B∩A3|=15
#
#     A1 U A2 U A3 = Set
#
#     Thus, 10+20+15 = 45
#
#     |B| = 45

# %% [markdown]
# #### Solution

# %% [markdown]
# ### Problem 3
#
# Do problem 14 from the End of Chapter Problems for Chapter 1 in the textbook.
#
#     (A)=0.4,P(B)=0.7,P(A∪B)=0.9
#
#      a.)
#         Rule of Addition:
#             P(AUB) = P(A) + P(B) - P(A∩B)
#             0.9 = (0.7 + 0.4) - P(A∩B)
#             P(A∩B) = 0.2
#      b.)
#          P(Ac∩B) = B - P(A∩B)
#                  = 0.7 - 0.2
#                  = 0.5
#
#      c.)
#          P(A-B) = P(A∩Bc)
#                 = P(A) - P(A∩B)
#                 = 0.4 - 0.2
#                 =0.2
#
#      d.)
#          P(Ac - B) = P(Ac∩Bc)
#                    = P(AUB)^c
#                    = 1 - P(AUB)
#                    = 1 - 0.9
#                    = 0.1
#
#
#      e.)
#
#            P(Ac∪B) = 1 - P(A) + P(A∩B)
#                    = 1 - 0.4 + 0.2
#                    = 0.8
#
#      f.)
#          P(A∩(B∪Ac)) = P(A∩B)
#                      = 0.2

# %% [markdown]
# #### Solution

# %% [markdown]
# ### Problem 4
#
# Do problem 15 from the End of Chapter Problems for Chapter 1 in the textbook.
#
#
# a.)
#
#     There's a 1/6 chance that X2 will be a 4 since the sample space is {1,2,3,4,5,6} and it's asking for the probability that it'll be a 4.
#
# b.)
#
#
#     First we do 6 X 6 = 36 because that's the total possibilities. And the possibities that X1 + X2 = 7 are
#     1 + 6
#     2 + 5
#     3 + 4
#     4 + 3
#     5 + 2
#     6 + 1
#     we find that there are only 6 possibities which X1 + X2 = 7, thus the fraction is 6/36.
#     And 6/36 simplifies to 1/6.
#
#     1/6 is the probability.
#
# c.)
#
#     Because X1 can't be 2, it means it can be 1,3,4,5,6
#     so there's a 5/6 chance.
#
#     Because X2 => 4, it means it can be 4,5,6, so there's a 3/6 chance
#
#     Thus the probability is (5/6)*(3/6) which is 15/36 which simplifies to 5/12.

# %% [markdown]
# #### Solution

# %% [markdown]
# ### Problem 5 (Analyze a Random Experiment)
#
# Suppose that a study is being done on all families with 1, 2, or 3 children (all having different ages, i.e., no twins), and let the outcomes be the genders (G = girl and B = boy) of the children in each family in ascending order of their ages (e.g., BG means an older girl and a younger boy). Assume all possible configurations of genders and numbers of children is equally likely (i.e., this will be an equiprobable probability space). Let events A = "families where the oldest child is a boy" and B = "families with exactly two girls and any number of boys." **Analyze.**
#
#
#     The Sample Space S = { B, G, BG, GB, BB, GG, BBB, BBG, BGG, BGB, GBG, GGG, GGB, GBB }
#
#     P = 1/14
#
#     The Event A = { B, GB, BB, BBB, BGB, GGB, GBB}
#
#     Prob A = 7/14 ~ 1/2
#
#     P(A) = 1/2
#
#     The Event B = { GG, BGG, GBG, GGG, GGB }
#
#     Prob B = 5/14
#
#     P(B) = 5/14

# %% [markdown]
# #### Solution:

# %% [markdown]
# ### Problem 6 (Analyze a Random Experiment)
#
# Suppose that each time Wayne charges an item to his credit card, he rounds the amount to the nearest dollar in his records (assume that for x dollars, the amount x.50 is rounded to x + 1 dollars). The round-off error is defined as (recorded - actual); the units are dollars, so if Wayne charges $\$\$4.25$, he records it as $\$4$, and the round-off error is $\$-0.25$, but if he charges $\$4.75$, the value recorded is $\$5$ and the round-off error is $\$0.25$. Assume this is random, so that each time Wayne charges to his card, he performs a  random experiment whose outcome is the round-off error. Assume the outcomes are equiprobable.
#
# Let event A = "at most 3 cents is rounded off in either direction" (i.e., | recorded - actual | ≤ 0.03). **Analyze.** (No pre-sample space necessary.)
#
#
#
#
#           if it's x.50 then it's rounded to x + 1 dollars
#
#           else it'll round down.
#
#           Thus, we can form the sample space as
#
#           S = {-49, 50}
#
#           P = 1/0.50 - (-0.49) = 1/0.99
#
#           The event A can be presented as
#
#           Let event A = "at most 3 cents is rounded off in either direction" (i.e., | recorded - actual | ≤ 0.03)
#
#           Thus,
#
#           P(A) = P((Actual - Recorded) <= 0.03) + P((Recorded - Actual) <= 0.03))
#
#                = (2 * 0.03)/0.99
#
#                = 0.06

# %% [markdown]
# #### Solution

# %% [markdown]
# ### Problem 7
#
# Suppose we consider the random experiment of randomly choosing a *real number* $x$ in the range $[0..1)$ for example using a spinner as discussed in class. Give the probability of the following events occurring.
#
#   (a) x is larger than 0.29 but smaller than 0.54 (probability problems are often written, unfortunately, in English, so you have to translate, in this case into "0.29 < x < 0.54"),
#
#   (b) x is at least 0.29 but at most 0.54 (i.e., 0.29 ≤ x ≤ 0.54),
#
#   (c) the 3rd digit after the decimal point in x is 4 (e.g., 0.98<b>4</b>23... or 0.00<b>4</b>000...   or 0.44<b>4</b>44...  etc. ),
#
#   (d) x is the decimal representation of the value $2^{-k}$ for $k = 1, 2, 3, \ldots$.
#
#   (e) x is a rational number (can be expressed as a fraction).
#
# Hint: Consider the role of Axiom $P_3$ in (d) and (e).
#
#
#     a.) 0.29 < x < 0.54
#
#         0.54 - 0.29 = 0.25
#
#     b.) 0.29 <= x <= 0.54
#
#         0.54 - 0.29 = 0.25
#
#     c.)
#
#         The probability is 1/10 because there is a 1/10 chance of getting 4 and because it's with replacement, the first two digits after the decimal points don't matter.
#
#
#     d.)
#
#         The probability is 0 because K is infinite and this is a continous list.
#
#     e.)
#
#         The probability is 0.

# %% [markdown]
# #### Solution:

# %% [markdown]
# ### Problem 8
#
# Consider the random experiment of flipping a fair coin until a head appears. The result of the random experiment is the number of flips. Let E = "it takes an even number of flips." Give the probability P(E). **Analyze** this experiment.
#
# Show your reasoning, don't just give the answer.
#
# Hint: compare the sequence of probabilities in the case of an even number of flips, and the sequence of probabilities in the case of an odd number. There is a simple relationship between them.
#
#     S = { H, T }     H being head and T being tails
#
#     P = { 0.5 }      It's a fair coin, so it has to be 0.5
#
#     We know that since it has to be even, the first time a head appears during an even flip is 0.5^2.
#
#     0.5^2 + 0.5^4 + 0.5^6 + 0.5^8
#
#     We see from this that this is a infinite geometric sequence.
#
#     Thus we can use this information and the formula for infinite geometric sequence to create
#
#     (0.5^2)/(1-0.5^2)
#
#     (0.5^2) being the first of the sequence and (1-0.5^2) being the total
#
#     and we get
#
#     0.25/0.75
#
#     P(E) = 0.33

# %% [markdown]
# #### Solution

# %% [markdown]
# # Lab Problems:  Generating Random Numbers
#
# These problems will be discussed in Lab on Friday.

# %% [markdown]
# ### Linear-Congruential Hash Functions
#
# As you may recall from CS 112, hash functions map key values to locations (buckets) in a hash table: the hash function appears to be spreading the keys uniformly randomly over the locations, but in fact there is nothing random about it, since we can easily repeat the computation to find the key later. This is called <i>pseudo-random</i> behavior: the hash function is not random, but appears to be so unless you know the rule used to compute the hash function.
#
# The simplest hash functions use the *linear-congruential method* to map a positive integer key $k$ to a slot in the hash table using the following function:
#
# $$ \text{hash}(k)\ =\ (a \cdot k + c)\ \%\ m$$
#
# for suitable parameters $a$, $c$, and $m$. The slots in the hash table would be from $0$ to $m-1$.
#
# So, for example, for $a=8$, $c=3$, and $m=7$, then the keys 4, 7, 12, 3, and 8 would be mapped as follows:
#
#
# ![Screen%20Shot%202021-02-05%20at%2012.06.36%20PM.png](attachment:Screen%20Shot%202021-02-05%20at%2012.06.36%20PM.png)
#
# ### Linear-Congruential Random Number Generators
#
# The same approach can be used to generate a sequence of pseudo-random numbers, by simply applying the hash function successively to an initial *seed* value.
#
# Supposing we start with a `seed` value, we can generate a sequence of random numbers by applying the hash function successively to each number in the sequence:
#
# $$\begin{aligned}
#         n_0       &= \text{hash}(seed) \\
#         n_1       &= \text{hash}(n_0) \\
#         n_2       &= \text{hash}(n_1) \\
#                   & \ldots \\
#         n_{k+1}   &= \text{hash}(n_k) \\                 \\
#                   & \ldots \\
#   \end{aligned}$$
#
# For example, using the values for $a$, $c$, and $m$ as above, and starting with a seed of $0$, we would get
# the following sequence:
#
#       seed    =  0
#       hash(0) => 3            <=  This is the first pseudo-random value produced
#       hash(3) => 6
#       hash(6) => 2
#       hash(2) => 5
#       hash(5) => 1
#       hash(1) => 4
#       hash(4) => 0            <=  It eventually produced the seed, which is a
#                                   valid random value
#
# #### Not for credit (but don't skip!)
#
# Question 1:  What do you think happens if you continue to apply the hash function to this sequence?
#
#
# Question 2: Is it possible to generate more than $m$ different pseudo-random values? Why or why not?
#
# Question 3:   A *full-period generator* is one that generates $m$ different values (note that the seed is considered to be a valid value) before repeating. Is this a full-period generator?

# %% [markdown]
# We say that a number $n$ *divides* $m$ if $m\over n$ is an integer. For example, 4 divides 16 but does not divide 10.
# A *prime number* $q$ is a number which is only divided by 1 and itself; for example 7 is prime but 8 is not (since 2 divides 8). Two numbers $n$ and $m$ are *relatively prime* if the only number that divides both $m$ and $n$ is 1.
#
# A well-known mathematical result is the following:
#
# <b>Theorem:</b>   A linear-congruential random number generator is full-period if and only if:
#
# * $m$ and $c$ are relatively prime;
# * If $q$ is a prime number that divides $m$, then $q$ divides $a-1$;
# * If 4 divides $m$, then 4 divides $a-1$.
#
# This is a little weird and complicated, and it is best when designing a practical random number generator to use standard values that have been tested and found to be robust under
# various statistical tests (such as we will explore below). A good reference with
# a table of commonly used parameters may be found <a href="https://en.wikipedia.org/wiki/Linear_congruential_generator">here</a>.

# %% [markdown]
# #### NOTE: For the rest of this homework, for simplicity, when we say "random" we will really mean "pseudo-random."

# %% [markdown]
# ## Problem 9: Generating Random  Numbers
#
#
# In this problem we will investigate how to use the method just described to implement random number generators for floating-point numbers in the range $[0,1)$ and for integer values in a given range $[lo..hi]$.   These will essentially be our own versions of the functions `numpy.random.random()` and `numpy.random.randint(...)`.
#
# As a first step we will generate numbers in the range $[0 .. m)$ for a large integer $m$, and then modify this sequence to create our two functions.

# %% [markdown]
# ### (A)  Generating random Integers in the range $[0..m)$
#
# The first step is simply to implement the method shown above, providing a seed, and generating the $m$ values (since it is a full-period generator).  Complete the stub below and verify that it matches the example shown above.
#
# NOTE:  It is usually a good idea to test your code on a small example before using
# the large values which are necessary to get realistic test results.

# %%
a = 8                   
c = 3     
m = 7                  

# hash function using LC method
def hash(k):  
    return ((a*k+ c) % m)        # Your code here      

next_random_value = 0                # to declare a variable we have to use a value, so use 0

# instantiate  next_random_value
def my_seed(s):
    global next_random_value         # note that you have to declare as global to modify it outside the function
    next_random_value = s

def my_random_integer():
        global next_random_value
        my_seed(hash(next_random_value))
        return next_random_value                             # Your code here

# Generate m random values (the last one will be the seed)

my_seed(0)

# should match values in example above (the sequence starts with 3 and ends with the seed 0)

for k in range(m):
    print(my_random_integer())
# Out:
# 3
# 6
# 2
# 5
# 1
# 4
# 0

# %% [markdown]
# Now try the same thing with a seed of 3, and observe that it generates $m$ values, the first being 6 and the last being the seed 3.

# %%
a = 8                   
c = 3     
m = 7                  

# hash function using LC method
def hash(k):  
    return ((a*k+ c) % m)        # Your code here      

next_random_value = 0                # to declare a variable we have to use a value, so use 0

# instantiate  next_random_value
def my_seed(s):
    global next_random_value         # note that you have to declare as global to modify it outside the function
    next_random_value = s

def my_random_integer():
        global next_random_value
        my_seed(hash(next_random_value))
        return next_random_value                             # Your code here

# Generate m random values (the last one will be the seed)

my_seed(3)

# should match values in example above (the sequence starts with 3 and ends with the seed 0)

for k in range(m):
    print(my_random_integer())
# Out:
# 6
# 2
# 5
# 1
# 4
# 0
# 3

# %% [markdown]
#  Next, print out the first 20 random numbers generated using the parameters which are used by the C language in its random number generator:
#
#      a = 1103515245
#      c = 12345
#      m = 2**31 = 2147483648
#
# Use a seed of 1.
#
# **Note:** This is one place where the dynamic list of variables is helpful: if you simply
# give definitions for these variables in the next cell, they will be used in
# the definition of `hash(...)` which is in a previous cell.  We will use these values below, and
# repeat them every time.

# %%
a = 1103515245
c = 12345
m = 2**31  

# with seed 1, first number is 1103527590
# with seed 1, last number is 1675546029

# Your code here
# hash function using LC method
def hash(k):  
    return ((a*k+ c) % m)        # Your code here      

next_random_value = 0                # to declare a variable we have to use a value, so use 0

# instantiate  next_random_value
def my_seed(s):
    global next_random_value         # note that you have to declare as global to modify it outside the function
    next_random_value = s

def my_random_integer():
        global next_random_value
        my_seed(hash(next_random_value))
        return next_random_value                             # Your code here

# Generate m random values (the last one will be the seed)

my_seed(1)

# should match values in example above (the sequence starts with 3 and ends with the seed 0)

for k in range(20):
    print(my_random_integer())
# Out:
# 1103527590
# 377401575
# 662824084
# 1147902781
# 2035015474
# 368800899
# 1508029952
# 486256185
# 1062517886
# 267834847
# 180171308
# 836760821
# 595337866
# 790425851
# 2111915288
# 1149758321
# 1644289366
# 1388290519
# 1647418052
# 1675546029

# %% [markdown]
# ### (B) Generating Random Floating-Point Numbers in the range $[0..1)$
# We want to write our own version of the function `numpy.random.random()` which we used
# in HW 01 (and will use in future homeworks), which essentially simulates the
# the "spinner" random experiment from lecture, which equiprobably returns a random float in the range $[0,1)$:
#
# ![Screen%20Shot%202020-01-30%20at%2012.32.05%20AM.png](attachment:Screen%20Shot%202020-01-30%20at%2012.32.05%20AM.png)
#
#
# To do this, it is simply necessary to convert integers in the range $[0 .. m)$ returned by <code>my_random_integer()</code> to floating-point numbers in the range $[0..1).$
#
# <blockquote>
#     Again, we are writing our own version of the Numpy function <code>np.random.random()</code> which you used in the first homework.  <b>You may NOT use the Numpy Random library</b>; we are learning how it was written!
#     That is why we added "my_" to the names of the functions in this homework. After this homework, we will go back
#     to use `numpy` functions, but then you will know how they are written!
# </blockquote>
#
#
# Hint: Easily done by division! You won't get all possible floating-point numbers, just
# $m$ floats evenly spaced throughout the interval $[0..1)$.

# %%
a = 1103515245
c = 12345
m = 2**31  

def my_random():
    return my_random_integer()/m                 # Your code here  

# Run this cell several times and verify that it works as you expect; try it with and
# without the seed

my_seed(0)

my_random()         # with seed 0, should get 5.748588591814041e-06
# Out:
# 5.748588591814041e-06

# %%
# Now test it by printing out 20 random floats in the range [0..1) using a seed of 5.
# Try it with and without the seed, but make sure the seed is uncommented before you
# Run All and submit

# with seed 5, first number should be 0.5693273963406682
# with seed 5, last number should be 0.7451900173909962

# Your code here

my_seed(5)

for i in range (20):
    print(my_random())
# Out:
# 0.5693273963406682
# 0.25809032237157226
# 0.3240002878010273
# 0.9728268985636532
# 0.3110656915232539
# 0.7923837187699974
# 0.5524904821068048
# 0.7222646162845194
# 0.9940482014790177
# 0.5969333662651479
# 0.9227651953697205
# 0.6458956864662468
# 0.6952493181452155
# 0.6491061891429126
# 0.34306331537663937
# 0.518370206002146
# 0.8771643685176969
# 0.030082283075898886
# 0.9786656610667706
# 0.7451900173909962

# %% [markdown]
# ###  (C) Pseudo-random Integers in range [lo..hi)
#
# Now we will use the `my_random()` function created in (B) to create random integers in a range $[lo..hi)$
# as if imitating <code>np.random.randint(lo,hi)</code>. Note that <code>lo</code> is an optional argument,
# so we want the following behavior, following <code>np.random.randint(...)</code>:
# <blockquote><pre>
#      np.random.randint(10)    #  returns a random value from [0..10)
#      np.random.randint(1,7)   #  returns a random value from [1..7)
# </pre></blockquote>
# This is a bit tricky, because the first argument is optional, where the second is not.
# The best way to do this is to collect the arguments in a list (see the <b>Optional Arguments</b> section right at the beginning of PythonFor237.ipynb for
# how to do this) and figure out how many and what
# they mean once you call the function.
#
# Having gotten the optional arguments to work, next we need to figure out how to
# create the appropriate values from <code>my_random()</code>.
#
#
# To do this, you will need to take the value returned by <code>my_random()</code> and (in this order):
#
#    - scale $[0..1)$ to $[0..(hi - lo))$ by multiplication
#    - shift $[0..(hi - lo))$ to $[lo .. hi)$ by addition
#    - convert to integers using <code>int(...)</code>.
#
# Note that the first two steps are a 1D version of what you did in 2D when you created the circle in Problem 5 in HW 01.

# %%
# Solution

# my_randint(hi) returns a random integer in the range [0..hi)
# my_randint(lo,hi) returns a random integer in the range [lo..hi)

def my_randint(lo, hi = None):          
      if (hi == None):                    
        return int(my_random() * lo)                            
      else:                                    
        return int((my_random()*(hi-lo))+ lo)
    
    
# Test itd using a seed of 0

my_seed(0)

    
print( [ my_randint(10)  for k in range(10) ] )  # should get [0, 6, 3, 6, 1, 5, 4, 6, 3, 2]
    
print() 

print( [ my_randint(2)  for k in range(10) ] )   # should get [0, 1, 0, 0, 1, 1, 1, 1, 0, 1]
    
print() 

print( [ my_randint(1,7)  for k in range(10) ] ) # should get [4, 2, 5, 5, 6, 2, 3, 5, 5, 2] 
                   
print() 

print( [ my_randint(0,10)  for k in range(10) ] ) # should get [0, 7, 0, 5, 2, 5, 5, 3, 1, 6]
# Out:
# [0, 6, 3, 6, 1, 5, 4, 6, 3, 2]
#
# [0, 1, 0, 0, 1, 1, 1, 1, 0, 1]
#
# [4, 2, 5, 5, 6, 2, 3, 5, 5, 2]
#
# [0, 7, 0, 5, 2, 5, 5, 3, 1, 6]

# %% [markdown]
# ## Problem 10: Testing for Randomness
#
# In this problem we will try three different tests for whether our functions are behaving
# randomly. These are rather informal, since all we will do is manipulate the random
# sequence in various ways and verify by inspection that it "looks random."
#
# Essentially, we will be repeating Problems 1 (B) and 3 from HW 01, but using our own versions of the random number generators.
#
# For further information on tests of randomness, see <a href="https://en.wikipedia.org/wiki/Statistical_randomness">this</a> Wikipedia page.

# %% [markdown]
# ### Part (A)  The Pair Test.
#
#  Now we will test our function <code>my_random()</code> developed above. For the first test, you must copy your solution to the Problem 1 (B) in HW 01,
#  and run it with your functions <code>my_seed(0)</code> and <code>my_random()</code>, instead of the numpy functions we used there.  You do NOT need to provide an estimate of $\pi$; all we are interested in is your visual
#  inspection of the distribution of the points in the unit square.
#
#  I will provide a solution to HW 01 on Saturday, after the late deadline has passed, in case you want to use my solution.
#
#
# Use a seed of 0 and let `num_trials = 5000`.
#
# Confirm by eye that the points appear to be random.

# %%
a = 1103515245
c = 12345
m = 2**31  

# Your code here  
def random_plane_plot(num_trials):
    x_vals = [ my_random() for i in range (num_trials)]            # Your code here
    y_vals = [ my_random() for i in range (num_trials)]            # Your code here
    plt.figure(num=None, figsize=(10, 10))
    plt.title('Graph of Uniform Distribution of '+str(num_trials)+' points in 2D.',fontsize=12)
    plt.grid(color='0.95')
    plt.ylim(0, 1)
    plt.xlim(0,1)
    plt.scatter(x_vals, y_vals,marker="o",color="r")
    plt.show()


my_seed(0)

random_plane_plot(5000)

# %% [markdown]
# ###  (B)  The Frequency Test
#
# For this part, we would like you to do a <i>frequency test</i>. This is essentially the same as Problem 3 of HW 01 where we determined whether the probability function was equinumerous (that is, all the bins were about the same height).  Essentially, what this amounts to is displaying the frequency distribution and examining its shape to verify that it conforms to what you would expect (of course, it will be an approximation of the ideal shape, which
# would get more precise as you do more trials).
#
# There is a subtle problem with this test and its relationship with the period of the random number generator: if you generate exactly as many numbers as in the period of `my_random_integer()`, then by definition the bins will be exactly the same size, since the sequence contains all possible numbers in the range $[0 .. 2^{31})$. (You could verify this by doing $m=2^{31}$ trials if you wish!)
#
# Another way to think of this is that the sequence is "more random" near the beginning than near the end, since near the end
# it can only choose numbers in the range $[0..2^{31})$ that have not yet been generated. The last number generated in the period is the seed, and hence not random at all!
#
# Hence we do not want to generate too much of the entire period to do this  test. We will therefore use only $10^6$ numbers, which represent
#
# $$\frac{10^6}{2^{31}} \, =\, 4.6566128730773926\text{e-04}$$
#
# or about 0.046 % of the period. This should be sufficiently random to do the test!
#
# <strong>Todo:</strong>
#
# Generate $10^6$ values using <code>my_randint(100)</code> with a seed of 0.
#
# Use `show_distribution(...)` from Problem 3 of HW 01 and simply observe that
# the bins are approximately the same height, as in HW 01.
#
# (I will post the solution for this on Saturday, after the late deadline passes).

# %%
# Solution

# Your code here


def show_distribution(outcomes, title='Probability Distribution'):
    num_trials = len(outcomes)
    C_list = Counter(outcomes)
    print(C_list)
    X = []
    Y = []
    for i in C_list:
        X.append(i)
    
    print(X)
    
    for i in C_list:
        Y.append(C_list[i]/num_trials)
    
    print(Y)   
    
                                        
    plt.bar(X,Y,width=1.0,edgecolor='black')
    plt.xlabel("Outcomes")
    plt.ylabel("Probability")
    plt.title(title)
    plt.show()
  



my_seed(0)
lis = []
num_trials = 10**6

for i in range(num_trials):
    lis.append(my_randint(100))
    

show_distribution(lis, title='Probability Distribution')
# Out:
# Counter({34: 10269, 24: 10228, 28: 10220, 83: 10185, 32: 10177, 0: 10162, 68: 10155, 71: 10153, 96: 10153, 87: 10145, 92: 10144, 69: 10137, 47: 10133, 4: 10113, 7: 10113, 77: 10113, 80: 10110, 43: 10108, 36: 10107, 15: 10099, 6: 10098, 23: 10097, 75: 10092, 37: 10090, 97: 10089, 9: 10084, 74: 10083, 79: 10082, 27: 10078, 76: 10078, 49: 10068, 84: 10061, 57: 10053, 60: 10051, 46: 10049, 33: 10045, 58: 10039, 5: 10032, 51: 10031, 88: 10027, 16: 10024, 44: 10023, 48: 10021, 59: 10014, 65: 10013, 40: 10013, 81: 10003, 30: 10002, 21: 10002, 98: 10000, 78: 9997, 82: 9996, 41: 9989, 12: 9988, 63: 9988, 72: 9984, 62: 9981, 39: 9979, 3: 9976, 73: 9974, 95: 9962, 70: 9961, 52: 9957, 14: 9954, 64: 9953, 55: 9949, 26: 9945, 93: 9942, 19: 9939, 54: 9938, 66: 9938, 22: 9935, 90: 9925, 20: 9925, 25: 9924, 11: 9922, 18: 9919, 67: 9915, 10: 9912, 2: 9905, 45: 9904, 31: 9901, 86: 9899, 61: 9891, 53: 9890, 42: 9889, 56: 9888, 85: 9874, 13: 9866, 89: 9859, 38: 9858, 50: 9854, 8: 9852, 17: 9850, 91: 9803, 1: 9793, 35: 9791, 94: 9783, 99: 9775, 29: 9742})
# [0, 65, 30, 67, 10, 51, 48, 60, 36, 25, 37, 82, 17, 29, 64, 78, 98, 80, 46, 53, 62, 24, 70, 71, 97, 32, 44, 73, 1, 4, 59, 55, 39, 18, 83, 12, 54, 69, 90, 61, 56, 14, 7, 8, 19, 89, 9, 45, 94, 79, 43, 2, 96, 15, 34, 74, 72, 5, 99, 3, 16, 63, 86, 49, 21, 28, 20, 88, 13, 6, 22, 35, 42, 91, 47, 57, 40, 92, 93, 66, 31, 11, 58, 84, 33, 81, 27, 77, 76, 68, 85, 95, 75, 52, 26, 23, 41, 87, 50, 38]
# [0.010162, 0.010013, 0.010002, 0.009915, 0.009912, 0.010031, 0.010021, 0.010051, 0.010107, 0.009924, 0.01009, 0.009996, 0.00985, 0.009742, 0.009953, 0.009997, 0.01, 0.01011, 0.010049, 0.00989, 0.009981, 0.010228, 0.009961, 0.010153, 0.010089, 0.010177, 0.010023, 0.009974, 0.009793, 0.010113, 0.010014, 0.009949, 0.009979, 0.009919, 0.010185, 0.009988, 0.009938, 0.010137, 0.009925, 0.009891, 0.009888, 0.009954, 0.010113, 0.009852, 0.009939, 0.009859, 0.010084, 0.009904, 0.009783, 0.010082, 0.010108, 0.009905, 0.010153, 0.010099, 0.010269, 0.010083, 0.009984, 0.010032, 0.009775, 0.009976, 0.010024, 0.009988, 0.009899, 0.010068, 0.010002, 0.01022, 0.009925, 0.010027, 0.009866, 0.010098, 0.009935, 0.009791, 0.009889, 0.009803, 0.010133, 0.010053, 0.010013, 0.010144, 0.009942, 0.009938, 0.009901, 0.009922, 0.010039, 0.010061, 0.010045, 0.010003, 0.010078, 0.010113, 0.010078, 0.010155, 0.009874, 0.009962, 0.010092, 0.009957, 0.009945, 0.010097, 0.009989, 0.010145, 0.009854, 0.009858]

# %% [markdown]
# ## Problem 11:  Further Tests of Randomness
#
# One of the characteristics of random sequences is that if you perform some simple
# transformation of the sequence, it should still be random. Various statistical tests of
# randomness are based on this idea. In this problem, we will transform the random sequences
# we generate using `my_randint(...)` to test for randomness in two ways (I have taken these from <a href="https://en.wikipedia.org/wiki/Statistical_randomness">here</a>) and test the derived sequences for randomness using the frequency test from the previous problem (which amounts to displaying the distribution of outcomes and examining its shape).
#
# *<b>The serial test:</b>  Generate two random digits using `my_randint(10)` and form a two-digit number from them (e.g., if you generated 8 and 3, then produce 83). Using this method, generate a long sequence of two-digit numbers
# and verify it is approximately equiprobable using the frequency test (as in Problem 10 (B)).
#
# *<b>The gap test:</b> Generate a sequence of 0's and 1's  using `my_randint(2)`  and find the distances between occurrences of 0's (00 would be a distance of 0, 010 would be a distance of 1, 01110 would be a distance of 3, etc.).
# Using this idea, generate a long sequence of such distances, and verify using the frequency test (it will not be equiprobably, see next paragraph).
#
# How to proceed:
#
# The serial test is essentially identical to Problem 10 (B) and you should get a very similar result. Just write a function `generate_two_digit_integer()` and use it in place of `my_randint(100)`
#
# The gap test is essentially  a trivial modification of the "Flip a coin until you get a head" experiment:  0 = heads, 1 = tails,
# and you are counting the number of tails instead of the total number of heads and tails. Write a function `generate_until_0()` which count the number of 1's generated until you get the first 0.
# You should get the following distribution:
#
#       S = { 0,   1,   2,   3,    ... }
#       P = { 1/2, 1/4, 1/8, 1/16, ... }

# %%
# (A) The Serial Test   Use a seed of 5 and num_trials = 10**6

# Your code here

def generate_two_digit_integer ():
    a = my_randint(10)
    b = my_randint(10)
   
    a = str(a)
    b = str(b)
    
    result = a+b
    
    
    return int(result)

my_seed(5)
num_trials = (10**6)
list = []

for i in range (num_trials):
    list.append(generate_two_digit_integer ())
    
show_distribution(list, title='Probability Distribution')
# Out:
# Counter({39: 10176, 6: 10161, 2: 10144, 93: 10142, 0: 10133, 83: 10132, 70: 10131, 69: 10130, 16: 10126, 9: 10124, 80: 10120, 78: 10119, 59: 10111, 62: 10106, 91: 10106, 48: 10103, 15: 10097, 86: 10096, 88: 10090, 36: 10089, 77: 10086, 34: 10084, 98: 10083, 72: 10081, 92: 10072, 67: 10070, 64: 10069, 97: 10068, 19: 10068, 50: 10068, 11: 10062, 94: 10061, 38: 10061, 52: 10058, 28: 10057, 40: 10057, 22: 10056, 45: 10047, 51: 10043, 12: 10040, 53: 10038, 57: 10030, 10: 10029, 8: 10027, 84: 10027, 75: 10023, 76: 10022, 54: 10022, 29: 10013, 27: 10013, 66: 10010, 3: 10010, 61: 10008, 71: 10007, 26: 10006, 74: 9999, 87: 9999, 30: 9993, 47: 9992, 68: 9988, 18: 9979, 7: 9979, 5: 9976, 37: 9974, 31: 9962, 65: 9962, 99: 9960, 41: 9957, 14: 9955, 13: 9953, 32: 9952, 82: 9947, 79: 9946, 96: 9940, 25: 9939, 89: 9939, 49: 9934, 58: 9931, 23: 9927, 73: 9926, 35: 9915, 24: 9914, 21: 9911, 85: 9910, 81: 9897, 55: 9890, 44: 9883, 17: 9874, 43: 9868, 20: 9844, 33: 9841, 95: 9833, 1: 9833, 60: 9829, 4: 9825, 46: 9806, 56: 9798, 90: 9798, 42: 9758, 63: 9752})
# [52, 39, 37, 57, 95, 96, 66, 35, 80, 97, 67, 82, 81, 2, 19, 86, 25, 20, 59, 16, 79, 15, 23, 14, 75, 92, 58, 56, 31, 0, 33, 63, 42, 88, 77, 22, 13, 49, 62, 24, 90, 12, 61, 55, 1, 94, 29, 26, 83, 28, 44, 43, 70, 64, 45, 76, 48, 60, 53, 32, 71, 11, 74, 46, 21, 38, 41, 10, 91, 69, 6, 3, 50, 47, 54, 17, 87, 93, 98, 9, 36, 68, 85, 73, 27, 99, 65, 4, 8, 18, 72, 84, 40, 5, 30, 51, 34, 7, 89, 78]
# [0.010058, 0.010176, 0.009974, 0.01003, 0.009833, 0.00994, 0.01001, 0.009915, 0.01012, 0.010068, 0.01007, 0.009947, 0.009897, 0.010144, 0.010068, 0.010096, 0.009939, 0.009844, 0.010111, 0.010126, 0.009946, 0.010097, 0.009927, 0.009955, 0.010023, 0.010072, 0.009931, 0.009798, 0.009962, 0.010133, 0.009841, 0.009752, 0.009758, 0.01009, 0.010086, 0.010056, 0.009953, 0.009934, 0.010106, 0.009914, 0.009798, 0.01004, 0.010008, 0.00989, 0.009833, 0.010061, 0.010013, 0.010006, 0.010132, 0.010057, 0.009883, 0.009868, 0.010131, 0.010069, 0.010047, 0.010022, 0.010103, 0.009829, 0.010038, 0.009952, 0.010007, 0.010062, 0.009999, 0.009806, 0.009911, 0.010061, 0.009957, 0.010029, 0.010106, 0.01013, 0.010161, 0.01001, 0.010068, 0.009992, 0.010022, 0.009874, 0.009999, 0.010142, 0.010083, 0.010124, 0.010089, 0.009988, 0.00991, 0.009926, 0.010013, 0.00996, 0.009962, 0.009825, 0.010027, 0.009979, 0.010081, 0.010027, 0.010057, 0.009976, 0.009993, 0.010043, 0.010084, 0.009979, 0.009939, 0.010119]

# %%
# (B) The Gap Test    Use a seed of 7 and num_trials = 10**6

# Your code here
'''
def gap_test ():
    one = 1
    zero = 0
    amount = 0
    current_num = my_randint(2)
    
    while(current_num == 1):
        current_num = my_randint(2)
    else:
        if(current_num == 0):
            current_num = my_randint(2)
            while (current_num != 0):
                amount += 1
                current_num = my_randint(2)
            else:
                return amount
'''

def gap_test ():
    one = 1
    zero = 0
    amount = 0
    current_num = my_randint(2)
    
    while(current_num != 0):
        amount += 1
        current_num = my_randint(2)
    else:
        return amount
    

my_seed(7)
num_trials = (10**6)
list = []

for i in range (num_trials):
    list.append(gap_test())
    
show_distribution(list, title='Probability Distribution')
# Out:
# Counter({0: 499632, 1: 249883, 2: 125104, 3: 62577, 4: 31457, 5: 15655, 6: 7788, 7: 4028, 8: 1880, 9: 1032, 10: 489, 11: 230, 12: 115, 13: 84, 14: 22, 15: 12, 16: 9, 20: 1, 18: 1, 17: 1})
# [1, 0, 2, 3, 4, 5, 6, 7, 8, 9, 12, 10, 11, 14, 13, 15, 20, 16, 18, 17]
# [0.249883, 0.499632, 0.125104, 0.062577, 0.031457, 0.015655, 0.007788, 0.004028, 0.00188, 0.001032, 0.000115, 0.000489, 0.00023, 2.2e-05, 8.4e-05, 1.2e-05, 1e-06, 9e-06, 1e-06, 1e-06]

# %% [markdown]
# ## Problem 12:
#
# Verify the result you calculated for Analytical Problem 8 above (the "flip until heads" experiment returns an even number)
# by running $10^6$ trials. The answer should be close to the result obtained by your mathematical analysis.
#
# You must
#
# (A) Print out the percentage of the total outcomes which were even (as a float, that is, 33 % would be 0.33), and
#
# (B) Display the distribution of even and odd outcomes (two bins, very simple!).  To produce a nice, informative display, you must label the X-axis with "even" and "odd" (by resetting
# the plt.xticks(...), see the `PythonFor237` notebook in the section on Bar Charts for an example). You will have to
# modify the `show_distribution` function to do this, or simply copy the body of the function into the code cell for your solution.
#
#
#
# Hints: For (B) you will need to convert your
# experimental outcomes to show whether the result was even or odd. The easiest
# way is to convert all even outcomes to 0 and all odd outcomes to 1, using
# a simple list comprehension.
#
# To find the percentage of 0's in the list of outcomes, use `Counter(...)`.

# %%
# Solution (A)            Use a seed of 2 and num_trials = 10**6


def show_distribution(outcomes, title='Probability Distribution'):
    num_trials = len(outcomes)
    C_list = Counter(outcomes)
    print(C_list)
    X = []
    Y = []
    for i in C_list:
        X.append(i)
    
    print(X)
    
    for i in C_list:
        Y.append(C_list[i]/num_trials)
    
    print(Y)   
                                         
    plt.bar(X,Y,width=1.0,edgecolor='black')
    plt.xlabel("Outcomes")
    plt.ylabel("Probability")
    plt.xticks(np.arange(2), ('odd', 'even'))
    plt.title(title)
    plt.show()
  
# Your code here

def gap_test ():
    one = 1
    zero = 0
    amount = 0
    current_num = my_randint(2)
    
    while(current_num != 0):
        amount += 1
        current_num = my_randint(2)
    else:
        return amount
    
list = []
my_seed(2)
num_trials = 10 ** 6
odd_even = [0, 0]

for i in range (num_trials):
    list.append(gap_test())

for x in(list):
    if (x%2==0):
        odd_even[1] += 1
    else:
        odd_even[0] += 1
        
X = []
for i in odd_even:
    X.append(i/num_trials)


print("Even is:" + " " + str(X[0]))

print("Odd is:" + " " + str(X[1]))
# Out:
# Even is: 0.333538
# Odd is: 0.666462

# %%
new_list = []
for i in range (odd_even[0]):
    new_list.append(1)
for i in range (odd_even[1]):
    new_list.append(0)
    
show_distribution(new_list, title='Probability Distribution')
# Out:
# Counter({0: 666462, 1: 333538})
# [1, 0]
# [0.333538, 0.666462]
